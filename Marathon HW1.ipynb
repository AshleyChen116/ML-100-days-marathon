# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w =0.3
b =0.5

# %%
x_lin = np.linspace(0, 100, 101)

# %%
y = (x_lin + np.random.randn(101) * 5) * w + b

# %%
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# 這邊的 y_hat, 就沒有隨機的部分了, 也就是下圖中的紅色實線部分
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
# 上面的 'b.' 是藍色點狀, 下面的 'r-' 是紅色線狀, label 是圖示上的名稱
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# Python 的函數是另一個新手上手的困難點, 由def開頭, 依序是函數名稱 / 輸入值, 冒號(:)結尾
# 最難讓人習慣的是 Python 的函式與條件判斷, 前後都沒有大括弧(其他程式常見), 而是以四格空白縮排來取代
# 以本例來說, mean_absolute_error 這個函數的定義範圍到 return mae 為止, 因為中間都是縮排, 而 """ 是多行註解(井號是單行註解)
# 函數中, sum(), abs(), len() 都是 Python 原有的方法, 因此可以直接呼叫
def mean_absolute_error(y, yp):  
    # MAE : 將兩個陣列相減後, 取絕對值(abs), 再將整個陣列加總成一個數字(sum), 最後除以y的長度(len), 因此稱為"平均絕對誤差"
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
MAE = mean_absolute_error(y, y_hat)
print(MAE)
# Out:
# 1.132502049785787

# %%
import math

# %%
def mse_value(y, yp):
    n = len(y)
    mse = sum(np.square(y - yp))/n
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %% [markdown]
# # 作業一 ：計算MSE

# %%
def Mean_Square_Error(y,yp):
  mse = MSE = sum((y - yp) ** 2) / len(y)
  return mse

MSE = Mean_Square_Error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 230.767

# %% [markdown]
# # 作業二

# %% [markdown]
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 你選的這組資料為何重要
#
# 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 蒐集而來的資料型態為何
#
# 這組資料想解決的問題如何評估

# %% [markdown]
# 你選的這組資料為何重要：十分符合國際目前疫情的情況，且期許能從中獲得一些以別於平常觀看新聞對於疫情趨勢情況的洞察。
#
# 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)：White House and a coalition of leading research groups / CORD-19 is a resource of over 134,000 scholarly articles, including over 60,000 with full text, about COVID-19, SARS-CoV-2, and related coronaviruses.
#
# 蒐集而來的資料型態為何：.json/.csv/.pdf/other
#
# 這組資料想解決的問題如何評估：透過文字探勘，期許夠過文字探看找出適合這些問題的洞察或是見解。

# %% [markdown]
# # 作業三

# %% [markdown]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)：如何提升更高的曝光，進而達成業績的提升
#
# 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)：乘客搭車APP的數位足跡
#
# 蒐集而來的資料型態為何：乘客歷史搭乘資訊的CSV檔案
#
# 你要回答的問題，其如何評估 (tips：你的假設如何驗證)：透過實際在特定幾個點運行，看看是否有效，再進一步擴大推行或是進行策略上運行的調整。
